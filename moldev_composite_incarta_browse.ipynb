# %% [markdown]
# ## Usage
# - Edit the settings in the cell below.
# - Cell -> Run All.
# - A Napari window will open, where you can scroll through your data.

# %%
colormap = ["blue", "green", "red"]

# %% [markdown]
# ## Code
# You don't need to make changes in the code cells below.

# %%
import dask.array as da
import glob
import matplotlib.pyplot as plt
import napari
import numpy as np
import os
import pandas as pd
import platform
from aicsimageio.aics_image import AICSImage
#from aicsimageio import AICSImage
from magicgui import magicgui
from pathlib import Path
from qtpy.QtWidgets import QVBoxLayout, QWidget, QLabel, QComboBox
from skimage.io import imread

# %%
PATH = 'Path'
DATE = 'Date'
TIMEPOINT = 'TimePoint'
ZSTEP = 'ZStep'
PLATE = 'Plate'
WELL = 'Well'
SITE = 'Site'
CHANNEL = 'Channel'
UUID = 'UUID'

def create_file_list(orig):
    print(orig)
    if not orig:
        return pd.DataFrame()
    
    metadata_columns = {
        'mc2': TIMEPOINT,
        'mc3': ZSTEP,
        'mc4': PLATE,
        'mc5': WELL,
        'mc6': SITE,
        'mc7': CHANNEL,
    }

    files = [(str(x)) for x in orig.glob("**/*.tif") if not "thumb" in x.name]
    df = pd.DataFrame(files, columns=[PATH])

    if not df.empty:
        print(files[-1])

    # Cross-platform pattern with dynamic column names
    pattern = (\
        r'[/\\](?P<{mc4}>[^/\\]*)'\
        + r'(?:[/\\][^/\\]*_Projection)?'\
        + r'(?:[/\\]timepoint\d+)?'\
        + r'[/\\]t(?P<{mc2}>\d+)_(?P<{mc5}>\w\d{{2}})_s(?P<{mc6}>\d{{1,2}})_(?P<{mc7}>w\d)_z(?P<{mc3}>\d+)'\
    ).format(**metadata_columns)
    #pattern = r'.*[/\\](?P<{mc1}>\d{{4}}-\d{{2}}-\d{{2}})[/\\][^/\\]*[/\\]TimePoint_(?P<{mc2}>\d+)(?:[/\\]ZStep_(?P<{mc3}>\d+))?[/\\](?P<{mc4}>[^_]+)_(?P<{mc5}>\w\d{{2}})_s(?P<{mc6}>\d)_(?P<{mc7}>w\d)'.format(**metadata_columns)
    #pattern = r'.*[/\\](?P<{mc1}>\d{{4}}-\d{{2}}-\d{{2}})[/\\][^/\\]*[/\\]TimePoint_(?P<{mc2}>\d+)(?:[/\\]ZStep_(?P<{mc3}>\d+))?[/\\](?P<{mc4}>[^_]+)_(?P<{mc5}>\w\d{{2}})_s(?P<{mc6}>\d)_(?P<{mc7}>w\d)(?P<{mc8}>[A-F0-9]{8}-[A-F0-9]{4}-[A-F0-9]{4}-[A-F0-9]{4}-[A-F0-9]{12})'.format(**metadata_columns)

    print(pattern)
    
    # Apply the regex pattern and extract the desired columns
    df_extracted = df[PATH].str.extract(pattern)
    print()

    # Add the extracted columns back to the original dataframe
    df = df.join(df_extracted)

    df[PLATE] = df[PLATE].astype(str)
    df[WELL] = df[WELL].astype(str)
    df[SITE] = df[SITE].astype(int)
    df[CHANNEL] = df[CHANNEL].astype(str)
    df[ZSTEP] = df[ZSTEP].astype(int)
    
    return df

# %%
TESTING = True
def get_stacks_and_projections(df):
    if TESTING:
        mask = df[SITE] < 3
        df = df[mask]
    
    # find channels with z-slices
    print(df.ZStep.unique())
    mask = df.ZStep > 1
    ch_z = df[mask][CHANNEL].unique()
    print(f'Channels with slices: {ch_z}')

    # find channels with projections (should be the same as ch_z)
    mask = df.ZStep == 0
    ch_p = df[mask][CHANNEL].unique()
    print(f'Channels with projections: {ch_p}')

    assert (np.sort(ch_z) == np.sort(ch_p)).all()
    
    # separate Z-slices and projection images
    mask_p = df[PATH].str.contains('_Projection/')

    mask_z = df[CHANNEL].isin(ch_z)
    if len(ch_z) == 0:
        mask_z = df[ZSTEP] == 1

    stacks = df[mask_z].copy().reset_index(drop=True)
    projs = df[mask_p].copy().reset_index(drop=True)

    stacks.sort_values(by=[PLATE, WELL, SITE, ZSTEP, CHANNEL], inplace=True, ignore_index=True)
    projs.sort_values(by=[PLATE, WELL, SITE, CHANNEL], inplace=True, ignore_index=True)
    
    print(f'stacks.shape: {stacks.shape}')
    print(f'projs.shape: {projs.shape}')
    
    return stacks, projs

# %%
def create_dask_array(grouped2d):
    # Dictionary to store Dask arrays for each plate
    plates = []
    plate_stack = None

    # Prebuild index mapping
    index_map = {}

    # Group by plate and well to handle multiple sites within a well
    for plate, plate_group in grouped2d.groupby(PLATE):
        wells = []

        # Iterate over each well
        for well, well_group in plate_group.groupby(WELL):
            sites = []

            # Iterate over each site
            for site, site_group in well_group.groupby(SITE):
                # At this point, we know the plate, well, and site
                # Add an entry to index_mapping for this site
                index_map[(plate, well, site)] = (len(plates), len(wells), len(sites))

                print(site_group.columns)
                print(site_group.shape)

                # Explode list columns
                exploded_site_group = site_group.explode([PATH, TIMEPOINT, CHANNEL])
                print(exploded_site_group.shape)
                print(exploded_site_group.apply(type).unique())
                print(exploded_site_group.head())

                channels = []

                # Iterate over each channel and stack them for the current Z-step
                for channel_path in exploded_site_group[PATH]:
                    print(plate, well, site, channel_path)
                    img = AICSImage(channel_path)
                    # Use img.get_image_dask_data() for lazy loading of data
                    dask_data = img.get_image_dask_data()
                    #print(dask_data.shape)
                    dask_data = dask_data.squeeze()
                    #print(dask_data.shape)
                    channels.append(dask_data)
                print()
                
                # Stack channels for the current site
                site_stack = da.stack(channels, axis=0)  # Stack Z-slices to form a 3D site-level array
                print(site_stack.shape)
                sites.append(site_stack)

            # Stack all site-level arrays into a well-level array
            well_stack = da.stack(sites, axis=0)  # Stack sites into a well
            wells.append(well_stack)

        # Stack all well-level arrays into a plate-level array
        plate_stack = da.stack(wells, axis=0)  # Stack wells into a plate
        plates.append(plate_stack)

    final_dask_array = da.stack(plates)
    return index_map, final_dask_array

# %%
def create_dask_array_with_z(grouped3d):
    # Dictionary to store Dask arrays for each plate
    plates = []
    plate_stack = None

    # Prebuild index mapping
    index_map = {}

    # Group by plate and well to handle multiple sites within a well
    for plate, plate_group in grouped3d.groupby(PLATE):
        wells = []

        # Iterate over each well
        for well, well_group in plate_group.groupby(WELL):
            sites = []

            # Iterate over each site
            for site, site_group in well_group.groupby(SITE):
                z_steps = []

                # At this point, we know the plate, well, and site
                # Add an entry to index_mapping for this site
                index_map[(plate, well, site)] = (len(plates), len(wells), len(sites))

                print(site_group.columns)
                print(site_group.shape)
                print(site_group[ZSTEP].apply(type).unique())  # Check the type of elements in the ZStep column
                #print(site_group[ZSTEP].head())  # Inspect the first few rows

                # Explode both ZStep and Channel columns to ensure they correspond correctly
                exploded_df = site_group.explode([PATH, TIMEPOINT, ZSTEP, CHANNEL])
                print(exploded_df.shape)
                print(exploded_df.apply(type).unique())
                print(exploded_df.head())

                # Group by ZStep to handle stacking of channels for each Z-slice
                for zstep, zstep_group in exploded_df.groupby(ZSTEP):
                    channels = []

                    # Iterate over each channel and stack them for the current Z-step
                    for channel_path in zstep_group[PATH]:
                        print(plate, well, site, zstep, channel_path)
                        img = AICSImage(channel_path)
                        # Use img.get_image_dask_data() for lazy loading of data
                        dask_data = img.get_image_dask_data()
                        #print(dask_data.shape)
                        dask_data = dask_data.squeeze()
                        #print(dask_data.shape)
                        channels.append(dask_data)

                    print()
                    # Stack channels along a new axis (assume channels have same shape)
                    z_step_stack = da.stack(channels, axis=0)  # Stack channels for this Z-step
                    z_steps.append(z_step_stack)

                print()
                # Stack Z-steps into a full 3D array for the current site
                site_stack = da.stack(z_steps, axis=0)  # Stack Z-slices to form a 3D site-level array
                print(site_stack.shape)
                sites.append(site_stack)

            # Stack all site-level arrays into a well-level array
            well_stack = da.stack(sites, axis=0)  # Stack sites into a well
            wells.append(well_stack)

        # Stack all well-level arrays into a plate-level array
        plate_stack = da.stack(wells, axis=0)  # Stack wells into a plate
        plates.append(plate_stack)

    final_dask_array = da.stack(plates)
    return index_map, final_dask_array

# %%
# First create viewer, so it can be used in NavigationWidget
viewer = napari.Viewer()

# Create a widget for navigation
IDX_WELL = 1
class NavigationWidget(QWidget):
    def __init__(self):
        super().__init__()
        layout = QVBoxLayout()
        
        # Well selection
        self.well_label = QLabel("Well")
        self.well_combo = QComboBox()
        self.well_combo.currentTextChanged.connect(self.update_image)

        # Adding widgets to layout
        layout.addWidget(self.well_label)
        layout.addWidget(self.well_combo)

        self.setLayout(layout)
        
        viewer.dims.events.point.connect(self._update_display)
        
    def update_wells(self, wells):
        self.wells = wells
        self.well_combo.clear()
        self.well_combo.addItems(wells)
        #self.well_selector.well.value = wells[0] if wells else None
        
    def _update_display(self):
        #print("_update_display")
        slider_index = viewer.dims.point[IDX_WELL]
        slider_index = round(slider_index)
        self.well_combo.setCurrentText(self.wells[slider_index])

    def update_image(self):
        well = self.well_combo.currentText()
        #print(well)  # Debugging print

        # Select data based on plate, well, and site
        if well in self.wells:
            viewer.dims.set_point(IDX_WELL, self.wells.index(well))

navigate_wells = NavigationWidget()

def get_lmu_active1():
    current_os = platform.system()
    
    if current_os == "Windows":
        return "L:\\lmu_active1"
    elif current_os == "Linux":
        return "/mnt/lmu_active1"
    else:
        raise ValueError(f"Unsupported operating system: {current_os}")
    
# Store the last selected folder
last_selected_folder = Path(get_lmu_active1()) / 'instruments/Micro'  # Default to home directory


@magicgui(
    folder={"label": "Select Folder", "mode": "d", "value": last_selected_folder},  # "d" stands for directory
)
def select_folder(folder: Path):
    if not folder or not folder.exists():
        print("Invalid folder")
        return
    
    last_selected_folder = folder  # Store the selected folder
    
    # create data frame with file list
    df = create_file_list(folder)
    # split file list to stacks and projections
    stacks, projs = get_stacks_and_projections(df)
    
    # read wavelengths from file list
    wavelengths = df.Channel.unique()
    wavelengths = sorted(wavelengths)
    
    viewer.layers.clear()  # Clear existing layers

    if not stacks.empty:
        grouped3d = stacks.groupby(by=[PLATE, WELL, SITE]).agg(list)
        index_map_3d, final_dask_array_3d = create_dask_array_with_z(grouped3d)
        n_zsteps = final_dask_array_3d.shape[3]
        
        plates = list(stacks[PLATE].unique())
        wells = list(stacks[WELL].unique())
        sites = list(stacks[SITE].unique())
        
        # Update the well dropdown
        navigate_wells.update_wells(wells)

        # Add 3D image with ZStep axis
        viewer.add_image(
            final_dask_array_3d, 
            channel_axis=4,  # Channel is 4th dimension in 3D
            name=wavelengths,
        )
    
        if not projs.empty:
            grouped_projs = projs.groupby(by=[PLATE, WELL, SITE]).agg(list)
            index_map_2d, final_dask_array_2d = create_dask_array(grouped_projs)
            # Expand 2D projection image to match the Z-axis length of the 3D image
            expanded_2d_da = da.repeat(final_dask_array_2d[:, :, :, None, :, :, :], repeats=n_zsteps, axis=3)

            names_2d = [w + " projection" for w in wavelengths]
            viewer.add_image(
                expanded_2d_da, 
                channel_axis=4,  # Channel is 4th dimension in 3D
                name=names_2d,
            )

        viewer.dims.axis_labels = ['Plate', 'Well', 'Site', 'Z-slice', 'X', 'Y']

        # start from Z-slice 0 to have labels visible
        # start from well 0 to match pull-down
        # start from site 0
        for i in range(len(viewer.dims.point)):
            print(i)
            viewer.dims.set_point(i,0)
            
    else:
        print('No images found (stacks.empty)')




viewer.window.add_dock_widget(select_folder)
viewer.window.add_dock_widget(navigate_wells)
napari.run()
# Out:
# /mnt/lmu_active1/instruments/Micro/solimai/WGA DAPI Stain/WGA DAPI Stain plate
# /mnt/lmu_active1/instruments/Micro/solimai/WGA DAPI Stain/WGA DAPI Stain plate/t1_C11_s25_w2_z1.tif
# [/\\](?P<Plate>[^/\\]*)(?:[/\\][^/\\]*_Projection)?(?:[/\\]timepoint\d+)?[/\\]t(?P<TimePoint>\d+)_(?P<Well>\w\d{2})_s(?P<Site>\d{1,2})_(?P<Channel>w\d)_z(?P<ZStep>\d+)
#
# [1]
# Channels with slices: []
# Channels with projections: []
# stacks.shape: (80, 7)
# projs.shape: (0, 7)
# Index(['Path', 'TimePoint', 'Channel', 'ZStep'], dtype='object')
# (1, 4)
# [<class 'list'>]
# (2, 4)
# [<class 'pandas.core.series.Series'>]
#                                                                              Path  \
# Plate                Well Site
# WGA DAPI Stain plate B02  1     /mnt/lmu_active1/instruments/Micro/solimai/WGA...
#                           1     /mnt/lmu_active1/instruments/Micro/solimai/WGA...
#
#                                TimePoint Channel ZStep
# Plate                Well Site
# WGA DAPI Stain plate B02  1            1      w1     1
#                           1            1      w2     1
# WGA DAPI Stain plate B02 1 1 /mnt/lmu_active1/instruments/Micro/solimai/WGA DAPI Stain/WGA DAPI Stain plate/t1_B02_s1_w1_z1.tif
# WGA DAPI Stain plate B02 1 1 /mnt/lmu_active1/instruments/Micro/solimai/WGA DAPI Stain/WGA DAPI Stain plate/t1_B02_s1_w2_z1.tif
#
#
# (1, 2, 1843, 1843)
# Index(['Path', 'TimePoint', 'Channel', 'ZStep'], dtype='object')
# (1, 4)
# [<class 'list'>]
# (2, 4)
# [<class 'pandas.core.series.Series'>]
#                                                                              Path  \
# Plate                Well Site
# WGA DAPI Stain plate B02  2     /mnt/lmu_active1/instruments/Micro/solimai/WGA...
#                           2     /mnt/lmu_active1/instruments/Micro/solimai/WGA...
#
#                                TimePoint Channel ZStep
# Plate                Well Site
# WGA DAPI Stain plate B02  2            1      w1     1
#                           2            1      w2     1
# WGA DAPI Stain plate B02 2 1 /mnt/lmu_active1/instruments/Micro/solimai/WGA DAPI Stain/WGA DAPI Stain plate/t1_B02_s2_w1_z1.tif
# WGA DAPI Stain plate B02 2 1 /mnt/lmu_active1/instruments/Micro/solimai/WGA DAPI Stain/WGA DAPI Stain plate/t1_B02_s2_w2_z1.tif
#
#
# (1, 2, 1843, 1843)
# Index(['Path', 'TimePoint', 'Channel', 'ZStep'], dtype='object')
# (1, 4)
# [<class 'list'>]
# (2, 4)
# [<class 'pandas.core.series.Series'>]
#                                                                              Path  \
# Plate                Well Site
# WGA DAPI Stain plate B03  1     /mnt/lmu_active1/instruments/Micro/solimai/WGA...
#                           1     /mnt/lmu_active1/instruments/Micro/solimai/WGA...
#
#                                TimePoint Channel ZStep
# Plate                Well Site
# WGA DAPI Stain plate B03  1            1      w1     1
#                           1            1      w2     1
# WGA DAPI Stain plate B03 1 1 /mnt/lmu_active1/instruments/Micro/solimai/WGA DAPI Stain/WGA DAPI Stain plate/t1_B03_s1_w1_z1.tif
# WGA DAPI Stain plate B03 1 1 /mnt/lmu_active1/instruments/Micro/solimai/WGA DAPI Stain/WGA DAPI Stain plate/t1_B03_s1_w2_z1.tif
#
#
# (1, 2, 1843, 1843)
# Index(['Path', 'TimePoint', 'Channel', 'ZStep'], dtype='object')
# (1, 4)
# [<class 'list'>]
# (2, 4)
# [<class 'pandas.core.series.Series'>]
#                                                                              Path  \
# Plate                Well Site
# WGA DAPI Stain plate B03  2     /mnt/lmu_active1/instruments/Micro/solimai/WGA...
#                           2     /mnt/lmu_active1/instruments/Micro/solimai/WGA...
#
#                                TimePoint Channel ZStep
# Plate                Well Site
# WGA DAPI Stain plate B03  2            1      w1     1
#                           2            1      w2     1
# WGA DAPI Stain plate B03 2 1 /mnt/lmu_active1/instruments/Micro/solimai/WGA DAPI Stain/WGA DAPI Stain plate/t1_B03_s2_w1_z1.tif
# WGA DAPI Stain plate B03 2 1 /mnt/lmu_active1/instruments/Micro/solimai/WGA DAPI Stain/WGA DAPI Stain plate/t1_B03_s2_w2_z1.tif
#
#
# (1, 2, 1843, 1843)
# Index(['Path', 'TimePoint', 'Channel', 'ZStep'], dtype='object')
# (1, 4)
# [<class 'list'>]
# (2, 4)
# [<class 'pandas.core.series.Series'>]
#                                                                              Path  \
# Plate                Well Site
# WGA DAPI Stain plate B04  1     /mnt/lmu_active1/instruments/Micro/solimai/WGA...
#                           1     /mnt/lmu_active1/instruments/Micro/solimai/WGA...
#
#                                TimePoint Channel ZStep
# Plate                Well Site
# WGA DAPI Stain plate B04  1            1      w1     1
#                           1            1      w2     1
# WGA DAPI Stain plate B04 1 1 /mnt/lmu_active1/instruments/Micro/solimai/WGA DAPI Stain/WGA DAPI Stain plate/t1_B04_s1_w1_z1.tif
# WGA DAPI Stain plate B04 1 1 /mnt/lmu_active1/instruments/Micro/solimai/WGA DAPI Stain/WGA DAPI Stain plate/t1_B04_s1_w2_z1.tif
#
#
# (1, 2, 1843, 1843)
# Index(['Path', 'TimePoint', 'Channel', 'ZStep'], dtype='object')
# (1, 4)
# [<class 'list'>]
# (2, 4)
# [<class 'pandas.core.series.Series'>]
#                                                                              Path  \
# Plate                Well Site
# WGA DAPI Stain plate B04  2     /mnt/lmu_active1/instruments/Micro/solimai/WGA...
#                           2     /mnt/lmu_active1/instruments/Micro/solimai/WGA...
#
#                                TimePoint Channel ZStep
# Plate                Well Site
# WGA DAPI Stain plate B04  2            1      w1     1
#                           2            1      w2     1
# WGA DAPI Stain plate B04 2 1 /mnt/lmu_active1/instruments/Micro/solimai/WGA DAPI Stain/WGA DAPI Stain plate/t1_B04_s2_w1_z1.tif
# WGA DAPI Stain plate B04 2 1 /mnt/lmu_active1/instruments/Micro/solimai/WGA DAPI Stain/WGA DAPI Stain plate/t1_B04_s2_w2_z1.tif
#
#
# (1, 2, 1843, 1843)
# Index(['Path', 'TimePoint', 'Channel', 'ZStep'], dtype='object')
# (1, 4)
# [<class 'list'>]
# (2, 4)
# [<class 'pandas.core.series.Series'>]
#                                                                              Path  \
# Plate                Well Site
# WGA DAPI Stain plate B05  1     /mnt/lmu_active1/instruments/Micro/solimai/WGA...
#                           1     /mnt/lmu_active1/instruments/Micro/solimai/WGA...
#
#                                TimePoint Channel ZStep
# Plate                Well Site
# WGA DAPI Stain plate B05  1            1      w1     1
#                           1            1      w2     1
# WGA DAPI Stain plate B05 1 1 /mnt/lmu_active1/instruments/Micro/solimai/WGA DAPI Stain/WGA DAPI Stain plate/t1_B05_s1_w1_z1.tif
# WGA DAPI Stain plate B05 1 1 /mnt/lmu_active1/instruments/Micro/solimai/WGA DAPI Stain/WGA DAPI Stain plate/t1_B05_s1_w2_z1.tif
#
#
# (1, 2, 1843, 1843)
# Index(['Path', 'TimePoint', 'Channel', 'ZStep'], dtype='object')
# (1, 4)
# [<class 'list'>]
# (2, 4)
# [<class 'pandas.core.series.Series'>]
#                                                                              Path  \
# Plate                Well Site
# WGA DAPI Stain plate B05  2     /mnt/lmu_active1/instruments/Micro/solimai/WGA...
#                           2     /mnt/lmu_active1/instruments/Micro/solimai/WGA...
#
#                                TimePoint Channel ZStep
# Plate                Well Site
# WGA DAPI Stain plate B05  2            1      w1     1
#                           2            1      w2     1
# WGA DAPI Stain plate B05 2 1 /mnt/lmu_active1/instruments/Micro/solimai/WGA DAPI Stain/WGA DAPI Stain plate/t1_B05_s2_w1_z1.tif
# WGA DAPI Stain plate B05 2 1 /mnt/lmu_active1/instruments/Micro/solimai/WGA DAPI Stain/WGA DAPI Stain plate/t1_B05_s2_w2_z1.tif
#
#
# (1, 2, 1843, 1843)
# Index(['Path', 'TimePoint', 'Channel', 'ZStep'], dtype='object')
# (1, 4)
# [<class 'list'>]
# (2, 4)
# [<class 'pandas.core.series.Series'>]
#                                                                              Path  \
# Plate                Well Site
# WGA DAPI Stain plate B06  1     /mnt/lmu_active1/instruments/Micro/solimai/WGA...
#                           1     /mnt/lmu_active1/instruments/Micro/solimai/WGA...
#
#                                TimePoint Channel ZStep
# Plate                Well Site
# WGA DAPI Stain plate B06  1            1      w1     1
#                           1            1      w2     1
# WGA DAPI Stain plate B06 1 1 /mnt/lmu_active1/instruments/Micro/solimai/WGA DAPI Stain/WGA DAPI Stain plate/t1_B06_s1_w1_z1.tif
# WGA DAPI Stain plate B06 1 1 /mnt/lmu_active1/instruments/Micro/solimai/WGA DAPI Stain/WGA DAPI Stain plate/t1_B06_s1_w2_z1.tif
#
#
# (1, 2, 1843, 1843)
# Index(['Path', 'TimePoint', 'Channel', 'ZStep'], dtype='object')
# (1, 4)
# [<class 'list'>]
# (2, 4)
# [<class 'pandas.core.series.Series'>]
#                                                                              Path  \
# Plate                Well Site
# WGA DAPI Stain plate B06  2     /mnt/lmu_active1/instruments/Micro/solimai/WGA...
#                           2     /mnt/lmu_active1/instruments/Micro/solimai/WGA...
#
#                                TimePoint Channel ZStep
# Plate                Well Site
# WGA DAPI Stain plate B06  2            1      w1     1
#                           2            1      w2     1
# WGA DAPI Stain plate B06 2 1 /mnt/lmu_active1/instruments/Micro/solimai/WGA DAPI Stain/WGA DAPI Stain plate/t1_B06_s2_w1_z1.tif
# WGA DAPI Stain plate B06 2 1 /mnt/lmu_active1/instruments/Micro/solimai/WGA DAPI Stain/WGA DAPI Stain plate/t1_B06_s2_w2_z1.tif
#
#
# (1, 2, 1843, 1843)
# Index(['Path', 'TimePoint', 'Channel', 'ZStep'], dtype='object')
# (1, 4)
# [<class 'list'>]
# (2, 4)
# [<class 'pandas.core.series.Series'>]
#                                                                              Path  \
# Plate                Well Site
# WGA DAPI Stain plate B07  1     /mnt/lmu_active1/instruments/Micro/solimai/WGA...
#                           1     /mnt/lmu_active1/instruments/Micro/solimai/WGA...
#
#                                TimePoint Channel ZStep
# Plate                Well Site
# WGA DAPI Stain plate B07  1            1      w1     1
#                           1            1      w2     1
# WGA DAPI Stain plate B07 1 1 /mnt/lmu_active1/instruments/Micro/solimai/WGA DAPI Stain/WGA DAPI Stain plate/t1_B07_s1_w1_z1.tif
# WGA DAPI Stain plate B07 1 1 /mnt/lmu_active1/instruments/Micro/solimai/WGA DAPI Stain/WGA DAPI Stain plate/t1_B07_s1_w2_z1.tif
#
#
# (1, 2, 1843, 1843)
# Index(['Path', 'TimePoint', 'Channel', 'ZStep'], dtype='object')
# (1, 4)
# [<class 'list'>]
# (2, 4)
# [<class 'pandas.core.series.Series'>]
#                                                                              Path  \
# Plate                Well Site
# WGA DAPI Stain plate B07  2     /mnt/lmu_active1/instruments/Micro/solimai/WGA...
#                           2     /mnt/lmu_active1/instruments/Micro/solimai/WGA...
#
#                                TimePoint Channel ZStep
# Plate                Well Site
# WGA DAPI Stain plate B07  2            1      w1     1
#                           2            1      w2     1
# WGA DAPI Stain plate B07 2 1 /mnt/lmu_active1/instruments/Micro/solimai/WGA DAPI Stain/WGA DAPI Stain plate/t1_B07_s2_w1_z1.tif
# WGA DAPI Stain plate B07 2 1 /mnt/lmu_active1/instruments/Micro/solimai/WGA DAPI Stain/WGA DAPI Stain plate/t1_B07_s2_w2_z1.tif
#
#
# (1, 2, 1843, 1843)
# Index(['Path', 'TimePoint', 'Channel', 'ZStep'], dtype='object')
# (1, 4)
# [<class 'list'>]
# (2, 4)
# [<class 'pandas.core.series.Series'>]
#                                                                              Path  \
# Plate                Well Site
# WGA DAPI Stain plate B08  1     /mnt/lmu_active1/instruments/Micro/solimai/WGA...
#                           1     /mnt/lmu_active1/instruments/Micro/solimai/WGA...
#
#                                TimePoint Channel ZStep
# Plate                Well Site
# WGA DAPI Stain plate B08  1            1      w1     1
#                           1            1      w2     1
# WGA DAPI Stain plate B08 1 1 /mnt/lmu_active1/instruments/Micro/solimai/WGA DAPI Stain/WGA DAPI Stain plate/t1_B08_s1_w1_z1.tif
# WGA DAPI Stain plate B08 1 1 /mnt/lmu_active1/instruments/Micro/solimai/WGA DAPI Stain/WGA DAPI Stain plate/t1_B08_s1_w2_z1.tif
#
#
# (1, 2, 1843, 1843)
# Index(['Path', 'TimePoint', 'Channel', 'ZStep'], dtype='object')
# (1, 4)
# [<class 'list'>]
# (2, 4)
# [<class 'pandas.core.series.Series'>]
#                                                                              Path  \
# Plate                Well Site
# WGA DAPI Stain plate B08  2     /mnt/lmu_active1/instruments/Micro/solimai/WGA...
#                           2     /mnt/lmu_active1/instruments/Micro/solimai/WGA...
#
#                                TimePoint Channel ZStep
# Plate                Well Site
# WGA DAPI Stain plate B08  2            1      w1     1
#                           2            1      w2     1
# WGA DAPI Stain plate B08 2 1 /mnt/lmu_active1/instruments/Micro/solimai/WGA DAPI Stain/WGA DAPI Stain plate/t1_B08_s2_w1_z1.tif
# WGA DAPI Stain plate B08 2 1 /mnt/lmu_active1/instruments/Micro/solimai/WGA DAPI Stain/WGA DAPI Stain plate/t1_B08_s2_w2_z1.tif
#
#
# (1, 2, 1843, 1843)
# Index(['Path', 'TimePoint', 'Channel', 'ZStep'], dtype='object')
# (1, 4)
# [<class 'list'>]
# (2, 4)
# [<class 'pandas.core.series.Series'>]
#                                                                              Path  \
# Plate                Well Site
# WGA DAPI Stain plate B09  1     /mnt/lmu_active1/instruments/Micro/solimai/WGA...
#                           1     /mnt/lmu_active1/instruments/Micro/solimai/WGA...
#
#                                TimePoint Channel ZStep
# Plate                Well Site
# WGA DAPI Stain plate B09  1            1      w1     1
#                           1            1      w2     1
# WGA DAPI Stain plate B09 1 1 /mnt/lmu_active1/instruments/Micro/solimai/WGA DAPI Stain/WGA DAPI Stain plate/t1_B09_s1_w1_z1.tif
# WGA DAPI Stain plate B09 1 1 /mnt/lmu_active1/instruments/Micro/solimai/WGA DAPI Stain/WGA DAPI Stain plate/t1_B09_s1_w2_z1.tif
#
#
# (1, 2, 1843, 1843)
# Index(['Path', 'TimePoint', 'Channel', 'ZStep'], dtype='object')
# (1, 4)
# [<class 'list'>]
# (2, 4)
# [<class 'pandas.core.series.Series'>]
#                                                                              Path  \
# Plate                Well Site
# WGA DAPI Stain plate B09  2     /mnt/lmu_active1/instruments/Micro/solimai/WGA...
#                           2     /mnt/lmu_active1/instruments/Micro/solimai/WGA...
#
#                                TimePoint Channel ZStep
# Plate                Well Site
# WGA DAPI Stain plate B09  2            1      w1     1
#                           2            1      w2     1
# WGA DAPI Stain plate B09 2 1 /mnt/lmu_active1/instruments/Micro/solimai/WGA DAPI Stain/WGA DAPI Stain plate/t1_B09_s2_w1_z1.tif
# WGA DAPI Stain plate B09 2 1 /mnt/lmu_active1/instruments/Micro/solimai/WGA DAPI Stain/WGA DAPI Stain plate/t1_B09_s2_w2_z1.tif
#
#
# (1, 2, 1843, 1843)
# Index(['Path', 'TimePoint', 'Channel', 'ZStep'], dtype='object')
# (1, 4)
# [<class 'list'>]
# (2, 4)
# [<class 'pandas.core.series.Series'>]
#                                                                              Path  \
# Plate                Well Site
# WGA DAPI Stain plate B10  1     /mnt/lmu_active1/instruments/Micro/solimai/WGA...
#                           1     /mnt/lmu_active1/instruments/Micro/solimai/WGA...
#
#                                TimePoint Channel ZStep
# Plate                Well Site
# WGA DAPI Stain plate B10  1            1      w1     1
#                           1            1      w2     1
# WGA DAPI Stain plate B10 1 1 /mnt/lmu_active1/instruments/Micro/solimai/WGA DAPI Stain/WGA DAPI Stain plate/t1_B10_s1_w1_z1.tif
# WGA DAPI Stain plate B10 1 1 /mnt/lmu_active1/instruments/Micro/solimai/WGA DAPI Stain/WGA DAPI Stain plate/t1_B10_s1_w2_z1.tif
#
#
# (1, 2, 1843, 1843)
# Index(['Path', 'TimePoint', 'Channel', 'ZStep'], dtype='object')
# (1, 4)
# [<class 'list'>]
# (2, 4)
# [<class 'pandas.core.series.Series'>]
#                                                                              Path  \
# Plate                Well Site
# WGA DAPI Stain plate B10  2     /mnt/lmu_active1/instruments/Micro/solimai/WGA...
#                           2     /mnt/lmu_active1/instruments/Micro/solimai/WGA...
#
#                                TimePoint Channel ZStep
# Plate                Well Site
# WGA DAPI Stain plate B10  2            1      w1     1
#                           2            1      w2     1
# WGA DAPI Stain plate B10 2 1 /mnt/lmu_active1/instruments/Micro/solimai/WGA DAPI Stain/WGA DAPI Stain plate/t1_B10_s2_w1_z1.tif
# WGA DAPI Stain plate B10 2 1 /mnt/lmu_active1/instruments/Micro/solimai/WGA DAPI Stain/WGA DAPI Stain plate/t1_B10_s2_w2_z1.tif
# (1, 2, 1843, 1843)
# Index(['Path', 'TimePoint', 'Channel', 'ZStep'], dtype='object')
# (1, 4)
# [<class 'list'>]
# (2, 4)
# [<class 'pandas.core.series.Series'>]
#                                                                              Path  \
# Plate                Well Site
# WGA DAPI Stain plate B11  1     /mnt/lmu_active1/instruments/Micro/solimai/WGA...
#                           1     /mnt/lmu_active1/instruments/Micro/solimai/WGA...
#
#                                TimePoint Channel ZStep
# Plate                Well Site
# WGA DAPI Stain plate B11  1            1      w1     1
#                           1            1      w2     1
# WGA DAPI Stain plate B11 1 1 /mnt/lmu_active1/instruments/Micro/solimai/WGA DAPI Stain/WGA DAPI Stain plate/t1_B11_s1_w1_z1.tif
# WGA DAPI Stain plate B11 1 1 /mnt/lmu_active1/instruments/Micro/solimai/WGA DAPI Stain/WGA DAPI Stain plate/t1_B11_s1_w2_z1.tif
#
#
# (1, 2, 1843, 1843)
# Index(['Path', 'TimePoint', 'Channel', 'ZStep'], dtype='object')
# (1, 4)
# [<class 'list'>]
# (2, 4)
# [<class 'pandas.core.series.Series'>]
#                                                                              Path  \
# Plate                Well Site
# WGA DAPI Stain plate B11  2     /mnt/lmu_active1/instruments/Micro/solimai/WGA...
#                           2     /mnt/lmu_active1/instruments/Micro/solimai/WGA...
#
#                                TimePoint Channel ZStep
# Plate                Well Site
# WGA DAPI Stain plate B11  2            1      w1     1
#                           2            1      w2     1
# WGA DAPI Stain plate B11 2 1 /mnt/lmu_active1/instruments/Micro/solimai/WGA DAPI Stain/WGA DAPI Stain plate/t1_B11_s2_w1_z1.tif
# WGA DAPI Stain plate B11 2 1 /mnt/lmu_active1/instruments/Micro/solimai/WGA DAPI Stain/WGA DAPI Stain plate/t1_B11_s2_w2_z1.tif
#
#
# (1, 2, 1843, 1843)
# Index(['Path', 'TimePoint', 'Channel', 'ZStep'], dtype='object')
# (1, 4)
# [<class 'list'>]
# (2, 4)
# [<class 'pandas.core.series.Series'>]
#                                                                              Path  \
# Plate                Well Site
# WGA DAPI Stain plate C02  1     /mnt/lmu_active1/instruments/Micro/solimai/WGA...
#                           1     /mnt/lmu_active1/instruments/Micro/solimai/WGA...
#
#                                TimePoint Channel ZStep
# Plate                Well Site
# WGA DAPI Stain plate C02  1            1      w1     1
#                           1            1      w2     1
# WGA DAPI Stain plate C02 1 1 /mnt/lmu_active1/instruments/Micro/solimai/WGA DAPI Stain/WGA DAPI Stain plate/t1_C02_s1_w1_z1.tif
# WGA DAPI Stain plate C02 1 1 /mnt/lmu_active1/instruments/Micro/solimai/WGA DAPI Stain/WGA DAPI Stain plate/t1_C02_s1_w2_z1.tif
#
#
# (1, 2, 1843, 1843)
# Index(['Path', 'TimePoint', 'Channel', 'ZStep'], dtype='object')
# (1, 4)
# [<class 'list'>]
# (2, 4)
# [<class 'pandas.core.series.Series'>]
#                                                                              Path  \
# Plate                Well Site
# WGA DAPI Stain plate C02  2     /mnt/lmu_active1/instruments/Micro/solimai/WGA...
#                           2     /mnt/lmu_active1/instruments/Micro/solimai/WGA...
#
#                                TimePoint Channel ZStep
# Plate                Well Site
# WGA DAPI Stain plate C02  2            1      w1     1
#                           2            1      w2     1
# WGA DAPI Stain plate C02 2 1 /mnt/lmu_active1/instruments/Micro/solimai/WGA DAPI Stain/WGA DAPI Stain plate/t1_C02_s2_w1_z1.tif
# WGA DAPI Stain plate C02 2 1 /mnt/lmu_active1/instruments/Micro/solimai/WGA DAPI Stain/WGA DAPI Stain plate/t1_C02_s2_w2_z1.tif
#
#
# (1, 2, 1843, 1843)
# Index(['Path', 'TimePoint', 'Channel', 'ZStep'], dtype='object')
# (1, 4)
# [<class 'list'>]
# (2, 4)
# [<class 'pandas.core.series.Series'>]
#                                                                              Path  \
# Plate                Well Site
# WGA DAPI Stain plate C03  1     /mnt/lmu_active1/instruments/Micro/solimai/WGA...
#                           1     /mnt/lmu_active1/instruments/Micro/solimai/WGA...
#
#                                TimePoint Channel ZStep
# Plate                Well Site
# WGA DAPI Stain plate C03  1            1      w1     1
#                           1            1      w2     1
# WGA DAPI Stain plate C03 1 1 /mnt/lmu_active1/instruments/Micro/solimai/WGA DAPI Stain/WGA DAPI Stain plate/t1_C03_s1_w1_z1.tif
# WGA DAPI Stain plate C03 1 1 /mnt/lmu_active1/instruments/Micro/solimai/WGA DAPI Stain/WGA DAPI Stain plate/t1_C03_s1_w2_z1.tif
#
#
# (1, 2, 1843, 1843)
# Index(['Path', 'TimePoint', 'Channel', 'ZStep'], dtype='object')
# (1, 4)
# [<class 'list'>]
# (2, 4)
# [<class 'pandas.core.series.Series'>]
#                                                                              Path  \
# Plate                Well Site
# WGA DAPI Stain plate C03  2     /mnt/lmu_active1/instruments/Micro/solimai/WGA...
#                           2     /mnt/lmu_active1/instruments/Micro/solimai/WGA...
#
#                                TimePoint Channel ZStep
# Plate                Well Site
# WGA DAPI Stain plate C03  2            1      w1     1
#                           2            1      w2     1
# WGA DAPI Stain plate C03 2 1 /mnt/lmu_active1/instruments/Micro/solimai/WGA DAPI Stain/WGA DAPI Stain plate/t1_C03_s2_w1_z1.tif
# WGA DAPI Stain plate C03 2 1 /mnt/lmu_active1/instruments/Micro/solimai/WGA DAPI Stain/WGA DAPI Stain plate/t1_C03_s2_w2_z1.tif
#
#
# (1, 2, 1843, 1843)
# Index(['Path', 'TimePoint', 'Channel', 'ZStep'], dtype='object')
# (1, 4)
# [<class 'list'>]
# (2, 4)
# [<class 'pandas.core.series.Series'>]
#                                                                              Path  \
# Plate                Well Site
# WGA DAPI Stain plate C04  1     /mnt/lmu_active1/instruments/Micro/solimai/WGA...
#                           1     /mnt/lmu_active1/instruments/Micro/solimai/WGA...
#
#                                TimePoint Channel ZStep
# Plate                Well Site
# WGA DAPI Stain plate C04  1            1      w1     1
#                           1            1      w2     1
# WGA DAPI Stain plate C04 1 1 /mnt/lmu_active1/instruments/Micro/solimai/WGA DAPI Stain/WGA DAPI Stain plate/t1_C04_s1_w1_z1.tif
# WGA DAPI Stain plate C04 1 1 /mnt/lmu_active1/instruments/Micro/solimai/WGA DAPI Stain/WGA DAPI Stain plate/t1_C04_s1_w2_z1.tif
#
#
# (1, 2, 1843, 1843)
# Index(['Path', 'TimePoint', 'Channel', 'ZStep'], dtype='object')
# (1, 4)
# [<class 'list'>]
# (2, 4)
# [<class 'pandas.core.series.Series'>]
#                                                                              Path  \
# Plate                Well Site
# WGA DAPI Stain plate C04  2     /mnt/lmu_active1/instruments/Micro/solimai/WGA...
#                           2     /mnt/lmu_active1/instruments/Micro/solimai/WGA...
#
#                                TimePoint Channel ZStep
# Plate                Well Site
# WGA DAPI Stain plate C04  2            1      w1     1
#                           2            1      w2     1
# WGA DAPI Stain plate C04 2 1 /mnt/lmu_active1/instruments/Micro/solimai/WGA DAPI Stain/WGA DAPI Stain plate/t1_C04_s2_w1_z1.tif
# WGA DAPI Stain plate C04 2 1 /mnt/lmu_active1/instruments/Micro/solimai/WGA DAPI Stain/WGA DAPI Stain plate/t1_C04_s2_w2_z1.tif
#
#
# (1, 2, 1843, 1843)
# Index(['Path', 'TimePoint', 'Channel', 'ZStep'], dtype='object')
# (1, 4)
# [<class 'list'>]
# (2, 4)
# [<class 'pandas.core.series.Series'>]
#                                                                              Path  \
# Plate                Well Site
# WGA DAPI Stain plate C05  1     /mnt/lmu_active1/instruments/Micro/solimai/WGA...
#                           1     /mnt/lmu_active1/instruments/Micro/solimai/WGA...
#
#                                TimePoint Channel ZStep
# Plate                Well Site
# WGA DAPI Stain plate C05  1            1      w1     1
#                           1            1      w2     1
# WGA DAPI Stain plate C05 1 1 /mnt/lmu_active1/instruments/Micro/solimai/WGA DAPI Stain/WGA DAPI Stain plate/t1_C05_s1_w1_z1.tif
# WGA DAPI Stain plate C05 1 1 /mnt/lmu_active1/instruments/Micro/solimai/WGA DAPI Stain/WGA DAPI Stain plate/t1_C05_s1_w2_z1.tif
#
#
# (1, 2, 1843, 1843)
# Index(['Path', 'TimePoint', 'Channel', 'ZStep'], dtype='object')
# (1, 4)
# [<class 'list'>]
# (2, 4)
# [<class 'pandas.core.series.Series'>]
#                                                                              Path  \
# Plate                Well Site
# WGA DAPI Stain plate C05  2     /mnt/lmu_active1/instruments/Micro/solimai/WGA...
#                           2     /mnt/lmu_active1/instruments/Micro/solimai/WGA...
#
#                                TimePoint Channel ZStep
# Plate                Well Site
# WGA DAPI Stain plate C05  2            1      w1     1
#                           2            1      w2     1
# WGA DAPI Stain plate C05 2 1 /mnt/lmu_active1/instruments/Micro/solimai/WGA DAPI Stain/WGA DAPI Stain plate/t1_C05_s2_w1_z1.tif
# WGA DAPI Stain plate C05 2 1 /mnt/lmu_active1/instruments/Micro/solimai/WGA DAPI Stain/WGA DAPI Stain plate/t1_C05_s2_w2_z1.tif
#
#
# (1, 2, 1843, 1843)
# Index(['Path', 'TimePoint', 'Channel', 'ZStep'], dtype='object')
# (1, 4)
# [<class 'list'>]
# (2, 4)
# [<class 'pandas.core.series.Series'>]
#                                                                              Path  \
# Plate                Well Site
# WGA DAPI Stain plate C06  1     /mnt/lmu_active1/instruments/Micro/solimai/WGA...
#                           1     /mnt/lmu_active1/instruments/Micro/solimai/WGA...
#
#                                TimePoint Channel ZStep
# Plate                Well Site
# WGA DAPI Stain plate C06  1            1      w1     1
#                           1            1      w2     1
# WGA DAPI Stain plate C06 1 1 /mnt/lmu_active1/instruments/Micro/solimai/WGA DAPI Stain/WGA DAPI Stain plate/t1_C06_s1_w1_z1.tif
# WGA DAPI Stain plate C06 1 1 /mnt/lmu_active1/instruments/Micro/solimai/WGA DAPI Stain/WGA DAPI Stain plate/t1_C06_s1_w2_z1.tif
#
#
# (1, 2, 1843, 1843)
# Index(['Path', 'TimePoint', 'Channel', 'ZStep'], dtype='object')
# (1, 4)
# [<class 'list'>]
# (2, 4)
# [<class 'pandas.core.series.Series'>]
#                                                                              Path  \
# Plate                Well Site
# WGA DAPI Stain plate C06  2     /mnt/lmu_active1/instruments/Micro/solimai/WGA...
#                           2     /mnt/lmu_active1/instruments/Micro/solimai/WGA...
#
#                                TimePoint Channel ZStep
# Plate                Well Site
# WGA DAPI Stain plate C06  2            1      w1     1
#                           2            1      w2     1
# WGA DAPI Stain plate C06 2 1 /mnt/lmu_active1/instruments/Micro/solimai/WGA DAPI Stain/WGA DAPI Stain plate/t1_C06_s2_w1_z1.tif
# WGA DAPI Stain plate C06 2 1 /mnt/lmu_active1/instruments/Micro/solimai/WGA DAPI Stain/WGA DAPI Stain plate/t1_C06_s2_w2_z1.tif
#
#
# (1, 2, 1843, 1843)
# Index(['Path', 'TimePoint', 'Channel', 'ZStep'], dtype='object')
# (1, 4)
# [<class 'list'>]
# (2, 4)
# [<class 'pandas.core.series.Series'>]
#                                                                              Path  \
# Plate                Well Site
# WGA DAPI Stain plate C07  1     /mnt/lmu_active1/instruments/Micro/solimai/WGA...
#                           1     /mnt/lmu_active1/instruments/Micro/solimai/WGA...
#
#                                TimePoint Channel ZStep
# Plate                Well Site
# WGA DAPI Stain plate C07  1            1      w1     1
#                           1            1      w2     1
# WGA DAPI Stain plate C07 1 1 /mnt/lmu_active1/instruments/Micro/solimai/WGA DAPI Stain/WGA DAPI Stain plate/t1_C07_s1_w1_z1.tif
# WGA DAPI Stain plate C07 1 1 /mnt/lmu_active1/instruments/Micro/solimai/WGA DAPI Stain/WGA DAPI Stain plate/t1_C07_s1_w2_z1.tif
#
#
# (1, 2, 1843, 1843)
# Index(['Path', 'TimePoint', 'Channel', 'ZStep'], dtype='object')
# (1, 4)
# [<class 'list'>]
# (2, 4)
# [<class 'pandas.core.series.Series'>]
#                                                                              Path  \
# Plate                Well Site
# WGA DAPI Stain plate C07  2     /mnt/lmu_active1/instruments/Micro/solimai/WGA...
#                           2     /mnt/lmu_active1/instruments/Micro/solimai/WGA...
#
#                                TimePoint Channel ZStep
# Plate                Well Site
# WGA DAPI Stain plate C07  2            1      w1     1
#                           2            1      w2     1
# WGA DAPI Stain plate C07 2 1 /mnt/lmu_active1/instruments/Micro/solimai/WGA DAPI Stain/WGA DAPI Stain plate/t1_C07_s2_w1_z1.tif
# WGA DAPI Stain plate C07 2 1 /mnt/lmu_active1/instruments/Micro/solimai/WGA DAPI Stain/WGA DAPI Stain plate/t1_C07_s2_w2_z1.tif
#
#
# (1, 2, 1843, 1843)
# Index(['Path', 'TimePoint', 'Channel', 'ZStep'], dtype='object')
# (1, 4)
# [<class 'list'>]
# (2, 4)
# [<class 'pandas.core.series.Series'>]
#                                                                              Path  \
# Plate                Well Site
# WGA DAPI Stain plate C08  1     /mnt/lmu_active1/instruments/Micro/solimai/WGA...
#                           1     /mnt/lmu_active1/instruments/Micro/solimai/WGA...
#
#                                TimePoint Channel ZStep
# Plate                Well Site
# WGA DAPI Stain plate C08  1            1      w1     1
#                           1            1      w2     1
# WGA DAPI Stain plate C08 1 1 /mnt/lmu_active1/instruments/Micro/solimai/WGA DAPI Stain/WGA DAPI Stain plate/t1_C08_s1_w1_z1.tif
# WGA DAPI Stain plate C08 1 1 /mnt/lmu_active1/instruments/Micro/solimai/WGA DAPI Stain/WGA DAPI Stain plate/t1_C08_s1_w2_z1.tif
#
#
# (1, 2, 1843, 1843)
# Index(['Path', 'TimePoint', 'Channel', 'ZStep'], dtype='object')
# (1, 4)
# [<class 'list'>]
# (2, 4)
# [<class 'pandas.core.series.Series'>]
#                                                                              Path  \
# Plate                Well Site
# WGA DAPI Stain plate C08  2     /mnt/lmu_active1/instruments/Micro/solimai/WGA...
#                           2     /mnt/lmu_active1/instruments/Micro/solimai/WGA...
#
#                                TimePoint Channel ZStep
# Plate                Well Site
# WGA DAPI Stain plate C08  2            1      w1     1
#                           2            1      w2     1
# WGA DAPI Stain plate C08 2 1 /mnt/lmu_active1/instruments/Micro/solimai/WGA DAPI Stain/WGA DAPI Stain plate/t1_C08_s2_w1_z1.tif
# WGA DAPI Stain plate C08 2 1 /mnt/lmu_active1/instruments/Micro/solimai/WGA DAPI Stain/WGA DAPI Stain plate/t1_C08_s2_w2_z1.tif
#
#
# (1, 2, 1843, 1843)
# Index(['Path', 'TimePoint', 'Channel', 'ZStep'], dtype='object')
# (1, 4)
# [<class 'list'>]
# (2, 4)
# [<class 'pandas.core.series.Series'>]
#                                                                              Path  \
# Plate                Well Site
# WGA DAPI Stain plate C09  1     /mnt/lmu_active1/instruments/Micro/solimai/WGA...
#                           1     /mnt/lmu_active1/instruments/Micro/solimai/WGA...
#
#                                TimePoint Channel ZStep
# Plate                Well Site
# WGA DAPI Stain plate C09  1            1      w1     1
#                           1            1      w2     1
# WGA DAPI Stain plate C09 1 1 /mnt/lmu_active1/instruments/Micro/solimai/WGA DAPI Stain/WGA DAPI Stain plate/t1_C09_s1_w1_z1.tif
# WGA DAPI Stain plate C09 1 1 /mnt/lmu_active1/instruments/Micro/solimai/WGA DAPI Stain/WGA DAPI Stain plate/t1_C09_s1_w2_z1.tif
#
#
# (1, 2, 1843, 1843)
# Index(['Path', 'TimePoint', 'Channel', 'ZStep'], dtype='object')
# (1, 4)
# [<class 'list'>]
# (2, 4)
# [<class 'pandas.core.series.Series'>]
#                                                                              Path  \
# Plate                Well Site
# WGA DAPI Stain plate C09  2     /mnt/lmu_active1/instruments/Micro/solimai/WGA...
#                           2     /mnt/lmu_active1/instruments/Micro/solimai/WGA...
#
#                                TimePoint Channel ZStep
# Plate                Well Site
# WGA DAPI Stain plate C09  2            1      w1     1
#                           2            1      w2     1
# WGA DAPI Stain plate C09 2 1 /mnt/lmu_active1/instruments/Micro/solimai/WGA DAPI Stain/WGA DAPI Stain plate/t1_C09_s2_w1_z1.tif
# WGA DAPI Stain plate C09 2 1 /mnt/lmu_active1/instruments/Micro/solimai/WGA DAPI Stain/WGA DAPI Stain plate/t1_C09_s2_w2_z1.tif
#
#
# (1, 2, 1843, 1843)
# Index(['Path', 'TimePoint', 'Channel', 'ZStep'], dtype='object')
# (1, 4)
# [<class 'list'>]
# (2, 4)
# [<class 'pandas.core.series.Series'>]
#                                                                              Path  \
# Plate                Well Site
# WGA DAPI Stain plate C10  1     /mnt/lmu_active1/instruments/Micro/solimai/WGA...
#                           1     /mnt/lmu_active1/instruments/Micro/solimai/WGA...
#
#                                TimePoint Channel ZStep
# Plate                Well Site
# WGA DAPI Stain plate C10  1            1      w1     1
#                           1            1      w2     1
# WGA DAPI Stain plate C10 1 1 /mnt/lmu_active1/instruments/Micro/solimai/WGA DAPI Stain/WGA DAPI Stain plate/t1_C10_s1_w1_z1.tif
# WGA DAPI Stain plate C10 1 1 /mnt/lmu_active1/instruments/Micro/solimai/WGA DAPI Stain/WGA DAPI Stain plate/t1_C10_s1_w2_z1.tif
#
#
# (1, 2, 1843, 1843)
# Index(['Path', 'TimePoint', 'Channel', 'ZStep'], dtype='object')
# (1, 4)
# [<class 'list'>]
# (2, 4)
# [<class 'pandas.core.series.Series'>]
#                                                                              Path  \
# Plate                Well Site
# WGA DAPI Stain plate C10  2     /mnt/lmu_active1/instruments/Micro/solimai/WGA...
#                           2     /mnt/lmu_active1/instruments/Micro/solimai/WGA...
#
#                                TimePoint Channel ZStep
# Plate                Well Site
# WGA DAPI Stain plate C10  2            1      w1     1
#                           2            1      w2     1
# WGA DAPI Stain plate C10 2 1 /mnt/lmu_active1/instruments/Micro/solimai/WGA DAPI Stain/WGA DAPI Stain plate/t1_C10_s2_w1_z1.tif
# WGA DAPI Stain plate C10 2 1 /mnt/lmu_active1/instruments/Micro/solimai/WGA DAPI Stain/WGA DAPI Stain plate/t1_C10_s2_w2_z1.tif
#
#
# (1, 2, 1843, 1843)
# Index(['Path', 'TimePoint', 'Channel', 'ZStep'], dtype='object')
# (1, 4)
# [<class 'list'>]
# (2, 4)
# [<class 'pandas.core.series.Series'>]
#                                                                              Path  \
# Plate                Well Site
# WGA DAPI Stain plate C11  1     /mnt/lmu_active1/instruments/Micro/solimai/WGA...
#                           1     /mnt/lmu_active1/instruments/Micro/solimai/WGA...
#
#                                TimePoint Channel ZStep
# Plate                Well Site
# WGA DAPI Stain plate C11  1            1      w1     1
#                           1            1      w2     1
# WGA DAPI Stain plate C11 1 1 /mnt/lmu_active1/instruments/Micro/solimai/WGA DAPI Stain/WGA DAPI Stain plate/t1_C11_s1_w1_z1.tif
# WGA DAPI Stain plate C11 1 1 /mnt/lmu_active1/instruments/Micro/solimai/WGA DAPI Stain/WGA DAPI Stain plate/t1_C11_s1_w2_z1.tif
#
#
# (1, 2, 1843, 1843)
# Index(['Path', 'TimePoint', 'Channel', 'ZStep'], dtype='object')
# (1, 4)
# [<class 'list'>]
# (2, 4)
# [<class 'pandas.core.series.Series'>]
#                                                                              Path  \
# Plate                Well Site
# WGA DAPI Stain plate C11  2     /mnt/lmu_active1/instruments/Micro/solimai/WGA...
#                           2     /mnt/lmu_active1/instruments/Micro/solimai/WGA...
#
#                                TimePoint Channel ZStep
# Plate                Well Site
# WGA DAPI Stain plate C11  2            1      w1     1
#                           2            1      w2     1
# WGA DAPI Stain plate C11 2 1 /mnt/lmu_active1/instruments/Micro/solimai/WGA DAPI Stain/WGA DAPI Stain plate/t1_C11_s2_w1_z1.tif
# WGA DAPI Stain plate C11 2 1 /mnt/lmu_active1/instruments/Micro/solimai/WGA DAPI Stain/WGA DAPI Stain plate/t1_C11_s2_w2_z1.tif
#
#
# (1, 2, 1843, 1843)
# 0
# 1
# 2
# 3
# 4
# 5

# %%
viewer.dims.point
